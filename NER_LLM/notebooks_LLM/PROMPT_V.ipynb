# %% [markdown]
# # Named Entity Recognition with LLMs
#
# In this notebook, we will show you how we applied NER to a set of literary-historical travelogues using [GPT4All](https://github.com/nomic-ai/gpt4all/tree/main/gpt4all-bindings/python).
# This tool allows you to experiment with generative Large Language Models on your local computer. The tool is privacy-friendly; as your data is not sent through an API - and results are reproducible.
# Be aware that running this code on your local computer may take a long time. Consider hooking up to a supercomputer or external server!
#
# Using the Jupyter Notebooks and data provided on our Github - you can choose to reproduce our results by re-running the code below, or (which is likely why you're here ;)) you can adapt the prompts to your own data!
#
# This code was developed to experiment with and evaluate different models and prompts across the languages English, French, Dutch and German.
# The prompts incrementally got more complex:
#
# 1. **Base prompt**: The model (in this case mistral, hermes or llama) is given a simple task: extract the fauna and flora entities from this text and transform it to JSON. After that, we feed the output to mistral to validate the JSON output. We chose mistral in this case as our tests showed that this was the most trustworthy model out of the three options to render valid JSON output.
# 2. **Persona**: we add a persona to the model ("You are a NER system trained on historical text material".).
# 3. **Annotation guide**: we add a more detailed explanation of the entities we expect to be tagged.
# 4. **Context**: we add more context (metadata) to the model by adding a title and author of the book the sentence came from.
# 5. **Few-shot examples**: we add a couple of labeled examples to the model to show it what we expect.
#
# In this Notebook, you will find the code for the last prompt as this is the most elaborate prompt which contains all the parts of prompts I-IV.

# %% [markdown]
# ## Load packages

# %%
import gpt4all
from gpt4all import GPT4All
import json
import pandas as pd
from sklearn.model_selection import train_test_split

import string
import re
import ast
from nervaluate import Evaluator
import nervaluate
import numpy as np

# %%
mistral_model = GPT4All("mistral-7b-instruct-v0.1.Q4_0.gguf")
hermes_model = GPT4All("nous-hermes-llama2-13b.Q4_0.gguf")
llama_model = GPT4All("Meta-Llama-3-8B-Instruct.Q4_0.gguf")

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Load data, split in dev, test and few-shot sample sets
#
# In this section, we will split the data in development (dev), test and few-shot sample sets.
# We stratify the data on the century column to ensure that all sets have a more or less equal distribution present of the centuries in the dataset (18, 19 and 20).
# For this experiment, we extract 100 samples for the dev set, 25 for a separate test set, and 10 for the few-shot samples.
#
#
# **STEPS**
# 1. Load data (LANG_fauna_flora_df_context_merged.csv). These can be found on our GitHub in the **Data** file.
# 2. Split in dev_1 and test set, stratify on century
# 3. Split dev_1 in dev and few shot samples.

# %%
df = pd.read_csv("/home/tess/generative_exp/Deliverables/fauna_flora_data/NL_fauna_flora_df_context_merged.csv")

# %%
#df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df.sample(5)
# Out:
#                        source_file  \
# 216    BHL_7_sample_Dutch_19.0.txt
# 106  BHL_794_sample_Dutch_18.0.txt
# 120  BHL_794_sample_Dutch_18.0.txt
# 295  BHL_957_sample_Dutch_19.0.txt
# 320  BHL_957_sample_Dutch_19.0.txt
#
#                                         text_aspect  \
# 216  ['middendorens', 'Melocactus', 'middendorens']
# 106                  ['vifch', 'vleefch', 'dieren']
# 120                                ['garft', 'vee']
# 295                                  ['Sparus Lin']
# 320                    ['Sideroxylon orichalciwnZ']
#
#                                         _sentence_text  \
# 216  In zeer enkele gevallen komt er een tweede der...
# 106  Van vifch en het vleefch van wilde dieren make...
# 120  Men zait maar wei- nig garft , en dat nog alle...
# 295                                       Sparus Lin .
# 320                         Sideroxylon orichalciwnZ .
#
#                       aspect_cat       ID  century  \
# 216  ['FLORA', 'FLORA', 'FLORA']    BHL_7       19
# 106  ['FAUNA', 'FAUNA', 'FAUNA']  BHL_794       18
# 120           ['FLORA', 'FAUNA']  BHL_794       18
# 295                    ['FAUNA']  BHL_957       19
# 320                    ['FLORA']  BHL_957       19
#
#                                                  title  \
# 216  Botanische excursie naar Nederlandsch West-Ind...
# 106                            Reis door Noord Amerika
# 120                            Reis door Noord Amerika
# 295  Verslag van het land, de bewoners en voortbren...
# 320  Verslag van het land, de bewoners en voortbren...
#
#                                              text_full              author  \
# 216  mm pil ii pr lir,iv m 7/rV,! m Ü50 m :: m "'.‘...  Suringar, W. F. R.
# 106  ■^ » -. ■i^^'Z  /Üè <=> UNIVERSITY OF PITTSBUR...         Kalm, Pehr,
# 120  ■^ » -. ■i^^'Z  /Üè <=> UNIVERSITY OF PITTSBUR...         Kalm, Pehr,
# 295   ( i4a ) VERSLAG van het Land, de Bewoners en ...         Macklot, H.
# 320   ( i4a ) VERSLAG van het Land, de Bewoners en ...         Macklot, H.
#
#                                                context
# 216  als ééne soort . De Candolle heeft ( Revue de ...
# 106  antwoord was , dat zy die ver naar 't Noorden ...
# 120  geploegd . Men zait gemeenlyk omtrent den 15 ....
# 295  i s s c h e n. de meeste Visschcn , welke wij ...
# 320  11 ( ? ) monogyna . Sagus mierocarpa .. Licual...

# %%
# sentences annotated per century
df["century"].value_counts()
# Out:
# century
# 19    261
# 18     99
# 20     18
# Name: count, dtype: int64

# %%
df["ID"].unique()
# Out:
# array(['DBNL_100', 'DBNL_102', 'DBNL_123', 'DBNL_149', 'DBNL_152',
#        'DBNL_170', 'DBNL_176', 'DBNL_189', 'DBNL_194', 'DBNL_199',
#        'DBNL_241', 'DBNL_259', 'DBNL_27', 'DBNL_33', 'DBNL_34', 'DBNL_43',
#        'DBNL_53', 'DBNL_87', 'BHL_61', 'BHL_794', 'BHL_7', 'BHL_957',
#        'DBNL_10', 'DBNL_151'], dtype=object)

# %%
# cast aspect cat and text_aspect to list objects 

df["aspect_cat"] = df.aspect_cat.apply(lambda x: eval(x))
df["text_aspect"] = df.text_aspect.apply(lambda x: eval(x))

# %%
# stratify by century
y = df[["century"]]

dev_1, test = train_test_split(df, test_size = 25, train_size=100, stratify = y, shuffle= True, random_state= 42) #add train_size=100 & test_size=25

# %%
dev, few_shot_samples = train_test_split(dev_1, test_size= 0.03)

# %%
# save test file
test.to_csv("test_Dutch.csv", index = False)

# save few-shot examples
few_shot_samples.to_csv("fewshot_Dutch.csv")

# save development set
dev.to_csv("dev_French.csv")

# %%
# read in our dev set
dev = pd.read_csv("dev_French.csv")

# %% [markdown]
# # Prompting
#
# In this section, we'll start prompting! From our few-shot samples, we extract two examples manually. We add samples for both the fauna and the flora categories. 🐱🍀

# %%
pd.get_option("display.max_colwidth")  # this is for your info only

pd.set_option("display.width", None)

# %%
few_shot_samples
# Out:
#    Unnamed: 0                      source_file  \
# 0         107   BHL_466_sample_French_20.0.txt
# 1          84   BHL_466_sample_French_20.0.txt
# 2          11  BHL_1025_sample_French_20.0.txt
# 3          90   BHL_466_sample_French_20.0.txt
# 4          99   BHL_466_sample_French_20.0.txt
# 5           6  BHL_1025_sample_French_20.0.txt
# 6         140      GB-141_sample_French_18.txt
# 7          25  BHL_1025_sample_French_20.0.txt
# 8         216      GB-267_sample_French_20.txt
# 9          21    BHL_2292_sample_French_18.xmi
#
#                                      text_aspect  \
# 0  ['CERATORHINÉS', 'Rhinocéros ( Ceratorhinus']
# 1   ['Brachyodus onoideus', 'coquilles marines']
# 2          ["pétales d'oran- ger à fruit aigre"]
# 3                                      ['faune']
# 4             ['Brachypodinés', 'Acérathérinés']
# 5                                   ['végétaux']
# 6                                  ['barbet-là']
# 7                  ['Mosquito', 'Culex pipiens']
# 8                       ['feuilles de palmiers']
# 9                                    ['bananes']
#
#                                       _sentence_text          aspect_cat  \
# 0  SoUS-FAMlLLE DES CERATORHINÉS Rhinocéros ( Cer...  ['FAUNA', 'FAUNA']
# 1  La présence du Brachyodus onoideus^ dans le fa...  ['FAUNA', 'FAUNA']
# 2  Je voudrais pouvoir envoyer en Europe de l'eau...           ['FLORA']
# 3  Nous rapportons plus volontiers . cette pièce ...           ['FAUNA']
# 4  Les Brachypodinés forment un groupe bien diffé...  ['FAUNA', 'FAUNA']
# 5  Il est rare pour moi depuis des an- nées de tr...           ['FLORA']
# 6  Ce barbet-là est probablement celui qui a suiv...           ['FAUNA']
# 7  Sans doute que Cuvier croit que le Mosquito es...  ['FAUNA', 'FAUNA']
# 8  Il est d'usage pour les femmes , à ce moment-l...           ['FLORA']
# 9  Un régime contient ordinairement depuis trente...           ['FLORA']
#
#          ID  century                                              title  \
# 0   BHL_466       20  Étude sommaire des mammifères fossiles des Fal...
# 1   BHL_466       20  Étude sommaire des mammifères fossiles des Fal...
# 2  BHL_1025       20  Aimé Bonpland, médecin et naturaliste, explo...
# 3   BHL_466       20  Étude sommaire des mammifères fossiles des Fal...
# 4   BHL_466       20  Étude sommaire des mammifères fossiles des Fal...
# 5  BHL_1025       20  Aimé Bonpland, médecin et naturaliste, explo...
# 6    GB_141       18                Souvenirs d'un sexagénaire, Tome IV
# 7  BHL_1025       20  Aimé Bonpland, médecin et naturaliste, explo...
# 8    GB_267       20                   L'Égypte d'hier et d'aujourd'hui
# 9  BHL_2292       18  Nouveau voyage aux isles de l'Amerique : conte...
#
#                                            text_full                   author  \
# 0   QBT •■A ?•"■■ G- Mri ?^â 9'û 9 5-L^s- l^arbar...           Mayet, Lucien,
# 1   QBT •■A ?•"■■ G- Mri ?^â 9'û 9 5-L^s- l^arbar...           Mayet, Lucien,
# 2  AIMÉ BONPLAND MÉDECIN ET NATURALISTE  EXPLORAT...              Hamy, E. T.
# 3   QBT •■A ?•"■■ G- Mri ?^â 9'û 9 5-L^s- l^arbar...           Mayet, Lucien,
# 4   QBT •■A ?•"■■ G- Mri ?^â 9'û 9 5-L^s- l^arbar...           Mayet, Lucien,
# 5  AIMÉ BONPLAND MÉDECIN ET NATURALISTE  EXPLORAT...              Hamy, E. T.
# 6  ﻿The Project Gutenberg EBook of Souvenirs d'un...  Antoine Vincent Arnault
# 7  AIMÉ BONPLAND MÉDECIN ET NATURALISTE  EXPLORAT...              Hamy, E. T.
# 8  ﻿The Project Gutenberg EBook of L'égypte, by W...           Walter Tyndale
# 9        NOUVEAU ^VOYAGE AUX ISLES DE L'AMERIQUE....    Labat, Jean Baptiste,
#
#                                              context
# 0  P2-M3 de R , siniorrensis conservée au Muséum ...
# 1  pas à les aborder ici . Fio . i8 . — Dicroceru...
# 2  fin de sep- tembre je serais de retour ici . A...
# 3  .3 , 4 , 5 , 6 a , 6 h , y , pi . VII , fig . ...
# 4  . Collection Lecointre , à Grillemont . Grande...
# 5  tout ce qui lui restait de forces « pour répon...
# 6  J'espérais qu'après tout son malheur n'était p...
# 7  à d'autres sans tenir parole ; je n'agis pas a...
# 8  fruits sont éclairés d'une douce lumière d'un ...
# 9  couvre prelque tout de petits boutons d'un jau...

# %%
few_shot_samples.iloc[9]["_sentence_text"]
# Out:
# "Un régime contient ordinairement depuis trente jusqu'à cinquante bananes selon la bonté du terrain."

# %%
# example 1 we'll feed to the model. 
example_sent_1 = few_shot_samples.iloc[0]["_sentence_text"]
example_output_1 = {
    "entities": {
        "fauna": ["CERATORHINÉS", "Rhinocéros ( Ceratorhinus"],
        "flora": [],
        },
}

# %%
# example 2 we'll feed to the model. 

example_sent_2= few_shot_samples.iloc[9]["_sentence_text"]
example_output_2 = {
    "entities": {
        "fauna": [],
        "flora": ["bananes"],
        },
}

# %% [markdown]
# ## Global template strings
#
# Below, we add some extra information which the model will need to make the output more predictable and easier to parse.
# First, we'll give the model a JSON-schema which we expect it to replicate. Then, we'll add the categories (annotation guide), personality (persona), and the question (task).

# %%
# Global template strings

schema_entity = {
    "entities": {
        "fauna": ["string"],
        "flora": ["string"],
        },
}

#category names with small global introduction/definition
categories = """FAUNA: common and scientific names of animals, taxa and animal species. 
FLORA: common and scientific names of plants, taxa and plant species."""

personality = "You are a named entity recognition system trained to recognize fauna and flora in historical texts."

question = "Extract the relevant named entities from the sentence."

# %% [markdown]
# ## LLM functions
#
# Here we construct our LLM pipe! The function ***text_extractor_llm*** is made to be fed a text, and (if all goes well), it will output the entities in a JSON-format.
# Then we feed the resulting JSON-object to our function ***json_to_lists***. This will try to parse the object and return a tuple with (categories, output).
# Adding the output of the first LLM's output was a design choice here because we wanted to analyze the ramblings of the LLM.
# Remove it if this is not what you're interested in!

# %%
def json_to_lists(json_obj):
    """"This function transforms the JSON-output in two different lists: aspect_cat_llm and aspect_text_llm"""
    cats = []
    output = []
    try:
        for category, result in json_obj["entities"].items():    
            for text_result in result:
                cats.append(category.upper())
                output.append(text_result)

        return (cats, output)
    except:
        print(json_obj)
        return ("Failed to parse")

# %%
# Toepassen van LLM-pipe op alle zinnen
# Functie neemt tekst, doorloopt hele pipeline op tekst en output een JSON-response

def text_extractor_llm(txt, author, title, example_sent_1, example_output_1, example_sent_2, example_output_2, main_model = mistral_model):
    """This function takes a text and applies the following steps:
    1) PROMPT: extract the entities using a global template variable + model (global)
    2) PROMPT: extract the JSON string from the output
    3) PROMPT: validate the JSON string 
    4) JSON_LOADS: cast to JSON object
    5) apply parsing function
    """
    
    sentence = txt
    
    template = f"""{personality} Your task is to identify the named entities in a sentence. 
Named entities include {categories}. 
Structure the answer according to {schema_entity}. 
Only look at the sentence, do not add anything else.
The sentence is indicated by <<<>>>. 

The author of the text is {author}.
The text is titled {title}.

Here are examples to help you:
Sentence: {example_sent_1}
Answer: {example_output_1}

Sentence: {example_sent_2}
Answer: {example_output_2}

Question: {question}.
Sentence: <<<{sentence}>>>

Answer: """
    
    output = main_model.generate(template, max_tokens = 200, temp = 0.01)
    print(output) # activate this if you want to follow along with the output of our main model. 
    
    #output = output.split("\n")
    
    #first_output = output[0]
    
    #first_output = "$" + first_output + "$"
    
    temp_json = f"""Extract the first JSON from the string. The string is indicated by $$.
Output: {output}.
JSON: """

    extract_json = mistral_model.generate(temp_json, max_tokens = 200, temp = 0.01)
    print(extract_json) # activate this if you want to double-check in the terminal if the output was indeed transformed to a JSON-object.
    
    
    temp_validate = f"""Transform the string to valid JSON. 
    Do not hallucinate new sentences.
The string is indicated by <<<>>>.
String: <<<{extract_json}>>>.
Answer: """

    validate_json = mistral_model.generate(temp_validate, max_tokens= 200, temp = 0.01)
    print(validate_json) # activate this if you want to check if your returned JSON-object was indeed validated correctly.
    
    
    try:
        json_obj = json.loads(validate_json)
        return (json_to_lists(json_obj), output)
    except: # If the casting to a JSON-object fails, the model will return the JSON-object below and print a warning.
        json_obj =  """{
"entities": {
    "fauna": [
        "string"
    ]
}
}"""
        json_obj = json.loads(json_obj)
        print("PARSING FAILED. Original result:")
        print(validate_json)

# %% [markdown]
# ## Apply the function to our Pandas Dataframe.

# %%
dev["results_LLM"] = dev.apply(lambda x: text_extractor_llm(x._sentence_text, x.author, x.title, example_sent_1, example_output_1, example_sent_2, example_output_2), axis = 1)
# Out:
# {'entities': {'fauna': ['dunes crevées', 'pierres énormes', 'maisons lézardées', 'gabares de pêche'], 'flora': ['palus', 'jardins maraîchers']}}
#
# {"entities": {"fauna": ["dunes crevées", "pierres énormes", "maisons lézardées", "gabares de pêche"], "flora": ["palus", "jardins maraîchers"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "dunes crevées",
#             "pierres énormes",
#             "maisons lézardées",
#             "gabares de pêche"
#         ],
#         "flora": [
#             "palus",
#             "jardins maraîchers"
#         ]
#     }
# }
#
# {'entities': {'fauna': ['Macrotherium sansaniense'], 'flora': []}}
#
# {"entities": {"fauna": ["Macrotherium sansaniense"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Macrotherium sansaniense"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Rhinocéros ( Ceratorhinus)', 'cf. simorrensis'], 'flora': []}}
#
# {"entities": {"fauna": ["Rhinoceros (Diceros bicornis)", "Crocodylus niloticus"], "flora": ["Euphorbia antiquorum"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "Rhinoceros (Diceros bicornis)",
#             "Crocodylus niloticus"
#         ],
#         "flora": [
#             "Euphorbia antiquorum"
#         ]
#     }
# }
#
# {'entities': {'fauna': ['chauves-souris'], 'flora': []}}
#
# {"entities": {"fauna": ["chauves-souris"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "chauves-souris"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['morues'], 'flora': []}}
#
# {"entities": {"fauna": ["morue"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "morue"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['animaux'], 'flora': []}}
#
# {"entities": {"fauna": ["animaux"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "animaux"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['palmiers', 'oranges'], 'flora': []}}
#
# {"entities": {"fauna": ["palmiers", "oranges"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "palmiers",
#         "oranges"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': [''], 'flora': ['arbres', 'très']}}
#
# {"entities": {"fauna": ["lion", "tigre"], "flora": ["plantes", "beaux"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "tigre"
#     ],
#     "flora": [
#         "plantes",
#         "beaux"
#     ]
# }
# }
#
# {'entities': {'fauna': ['ours'], 'flora': []}}
#
# {"entities": {"fauna": ["ours"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "ours"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['papillons aux éclats métalliques', 'sphynx à tête de mort', 'minuscule papillon bleu'], 'flora': []}}
#
# {"entities": {"fauna": ["papillons aux éclats métalliques", "sphynx à tête de mort", "minuscule papillon bleu"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "papillons aux éclats métalliques",
#             "sphynx à tête de mort",
#             "minuscule papillon bleu"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': ['ânes'], 'flora': []}}
#
# {"entities": {"fauna": ["águila"], "flora": ["árbol"]}}
#
# {
# "entities": {
#     "fauna": [
#         "águila"
#     ],
#     "flora": [
#         "árbol"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Rhinocéros (Ceratorhinus)'], 'flora': []}}
#
# {"entities": {"fauna": ["Rhinoceros"], "flora": ["Pinus"]}}
#
# {
# "entities": {
#     "fauna": [
#         "Rhinoceros"
#     ],
#     "flora": [
#         "Pinus"
#     ]
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['blé']}}
#
# {"entities": {"fauna": ["lion"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "lion"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['gros lion'], 'flora': []}}
#
# {"entities": {"fauna": ["gros lion"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "gros lion"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['herbes sèches']}}
#
# {"entities": {"fauna": ["oiseau"], "flora": ["arbre", "herbe"]}}
#
# {
# "entities": {
#     "fauna": [
#         "oiseau"
#     ],
#     "flora": [
#         "arbre",
#         "herbe"
#     ]
# }
# }
#
# {'entities': {'fauna': ['dauphin', 'singe'], 'flora': []}}
#
# {"entities": {"fauna": ["dauphin", "singe"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "dauphin",
#         "singe"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['arbres'], 'flora': []}}
#
# {"entities": {"fauna": ["arbres"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "arbres"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Grand Anoplotherium', 'Pan- golin gigantesque']}}
#
# {"entities": {"fauna": ["Grand Anoplotherium", "Pangolin gigantesque"]}}
#
# {
# "entities": {
#     "fauna": [
#         "Grand Anoplotherium",
#         "Pangolin gigantesque"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Anisodon', 'gnum'], 'flora': []}}
#
# {"entities": {"fauna": ["Anisodon", "gnum"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Anisodon",
# "gnum"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Rhinocéros ( Ceratorhinus)', 'Mourzouk', 'Barth s\'egare', 'Touaregs', 'Dunes', 'Afalesselez', 'Bubales et moufflons', 'Ouragan', 'Kano', 'Yola', 'Ouélad-Sliman', 'Erreur des Européens sur le centre de l\'Afrique'], 'flora': ['bananes', 'palais des démons', 'agadez', 'dénivelés', 'baobab', 'baghirmi', 'girafe', 'soudan', 'dendal', 'chasse à l\'homme', 'lacs remarquables', 'activité des fourmis', 'ghaladina de sokoto', 'vallée de foga', 'zogirma
#
# {'entities': {'fauna': ['Rhinocéros ( Ceratorhinus)', 'Mourzouk', 'Barth s\'egare', 'Touaregs', 'Dunes', 'Afalesselez', 'Bubales et moufflons', 'Ouragan', 'Kano', 'Yola', 'Ouélad-Sliman', 'Erreur des Européens sur le centre de l\'Afrique'], 'flora': ['bananes', 'palais des démons', 'agadez', 'dénivelés', 'baobab', 'baghirmi', 'girafe', 'soudan', 'dendal', 'chasse à l\'homme', 'lacs remarquables', 'activité des fourmis', 'ghaladina de sokoto', 'vallée de foga', 'zogir
#
# {
# "entities": {
# "fauna": [
# "Rhinocéros ( Ceratorhinus)",
# "Mourzouk",
# "Barth s\'egare",
# "Touaregs",
# "Dunes",
# "Afalesselez",
# "Bubales et moufflons",
# "Ouragan",
# "Kano",
# "Yola",
# "Ouélad-Sliman",
# "Erreur des Européens sur le centre de l\'Afrique"
# ],
# "flora": [
# "bananes",
# "palais des démons",
# "agadez",
# "dénivelés",
# "baobab",
# "baghirmi",
# "girafe",
# "soudan",
# "dendal",
# "chasse à l\'homme",
# "lacs remarquables
# PARSING FAILED. Original result:
#
# {
# "entities": {
# "fauna": [
# "Rhinocéros ( Ceratorhinus)",
# "Mourzouk",
# "Barth s\'egare",
# "Touaregs",
# "Dunes",
# "Afalesselez",
# "Bubales et moufflons",
# "Ouragan",
# "Kano",
# "Yola",
# "Ouélad-Sliman",
# "Erreur des Européens sur le centre de l\'Afrique"
# ],
# "flora": [
# "bananes",
# "palais des démons",
# "agadez",
# "dénivelés",
# "baobab",
# "baghirmi",
# "girafe",
# "soudan",
# "dendal",
# "chasse à l\'homme",
# "lacs remarquables
#
# {'entities': {'fauna': ['bête'], 'flora': []}}
#
# {"entities": {"fauna": ["bête"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "bête"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['chevaux'], 'flora': []}}
#
# {"entities": {"fauna": ["chevaux"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "chevaux"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Pros'], 'flora': []}}
#
# {"entities": {"fauna": ["Pros"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Pros"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['chien'], 'flora': []}}
#
# {"entities": {"fauna": ["chien"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "chien"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['palmiers'], 'flora': ['oranges']}}
#
# {"entities": {"fauna": ["dogs"], "flora": ["roses"]}}
#
# {
# "entities": {
#     "fauna": [
#         "dogs"
#     ],
#     "flora": [
#         "roses"
#     ]
# }
# }
#
# {'entities': {'fauna': ['saules'], 'flora': ['prairies', 'verdoyantes']}}
#
# {"type": "location", "value": "Paris"}
#
# {
# "type": "location",
# "value": "Paris"
# }
# {'type': 'location', 'value': 'Paris'}
#
# {'entities': {'fauna': ['Palæotherium', 'Des'], 'flora': []}}
#
# {"entities": {"fauna": ["Palæotherium", "Des"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Palæotherium",
#         "Des"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['moutons', 'peaux'], 'flora': ['jardinets', 'Gentilly']}}
#
# {"entities": {"fauna": ["moutons", "peaux"], "flora": ["jardinets", "Gentilly"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "moutons",
#             "peaux"
#         ],
#         "flora": [
#             "jardinets",
#             "Gentilly"
#         ]
#     }
# }
#
# {'entities': {'fauna': ['papillons'], 'flora': ['cèdre du Liban']}}
#
# {"entities": {"fauna": ["papillons"], "flora": ["cèdre du Liban"]}}
#
# {
# "entities": {
#     "fauna": [
#         "papillons"
#     ],
#     "flora": [
#         "cèdre du Liban"
#     ]
# }
# }
#
# {'entities': {'fauna': ['girafe'], 'flora': []}}
#
# {"entities": {"fauna": ["giraffe"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "giraffe"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Brachyodus onoideus'], 'flora': []}}
#
# {"entities": {"fauna": ["Brachyodus onoideus"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Brachyodus onoideus"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': ['phalange ou phalangine', 'mammifères fossiles des faluns de la touraine'], 'flora': []}}
#
# {"entities": {"fauna": ["phalange ou phalangine", "mammifères fossiles des faluns de la touraine"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "phalange ou phalangine",
#             "mammifères fossiles des faluns de la touraine"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': [], 'flora': ['rivage', 'pauvre homme']}}
#
# {"entities": {"fauna": ["lion", "tigre"], "flora": ["rivage", "pauvre homme"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "lion",
#             "tigre"
#         ],
#         "flora": [
#             "rivage",
#             "pauvre homme"
#         ]
#     }
# }
#
# {'entities': {'fauna': ['palmiers'], 'flora': []}}
#
# {"entities": {"fauna": ["palmiers"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "palmiers"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['peaux de bêtes écorchées'], 'flora': []}}
#
# {"entities": {"fauna": ["peaux de bêtes écorchées"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "peaux de bêtes écorchées"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Anthracotherium onoideum'], 'flora': []}}
#
# {"entities": {"fauna": ["Anthracotherium onoideum"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Anthracotherium onoideum"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Dicrocerus elegans'], 'flora': []}}
#
# {"entities": {"fauna": ["Dicrocerus elegans"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Dicrocerus elegans"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['vertébrés'], 'flora': []}}
#
# {"entities": {"fauna": ["vertébrés"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "vert\u0301bres"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Brachyodus onoideus', 'fossile'], 'flora': []}}
#
# {"entities": {"fauna": ["Brachyodus onoideus", "fossile"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Brachyodus onoideus",
#         "fossile"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['JARDIN DES PLANTES']}}
#
# {"entities": {"fauna": ["LION"], "flora": ["TREE"]}}
#
# {
# "entities": {
#     "fauna": [
#         "LION"
#     ],
#     "flora": [
#         "TREE"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Flora Peruviana'], 'flora': []}}
#
# {"entities": {"fauna": ["Flora Peruviana"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Flora Peruviana"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Macrotherium grande', 'Ma- crotherium grande'], 'flora': []}}
#
# {"entities": {"fauna": ["Macrotherium grande", "Microtherium sp."], "flora": ["Psilotum nudum"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "Macrotherium grande",
#             "Microtherium sp."
#         ],
#         "flora": [
#             "Psilotum nudum"
#         ]
#     }
# }
#
# {'entities': {'fauna': [], 'flora': ['cuiller à café', 'fleurs d\'oranger']}}
#
# {"entities": {"fauna": ["oiseau"], "flora": ["cuiller à café", "fleurs d'oranger"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "oiseau"
#         ],
#         "flora": [
#             "cuiller à café",
#             "fleurs d'oranger"
#         ]
#     }
# }
#
# {'entities': {'fauna': ['Wirbelthiere', 'Silzungberichte'], 'flora': []}}
#
# {"entities": {"fauna": ["Wirbelthiere", "Silzungberichte"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Wirbelthiere",
#         "Silzungberichte"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['rats'], 'flora': []}}
#
# {"entities": {"fauna": ["rats"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "rats"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['B. onoideus', 'Brachiodontes'], 'flora': []}}
#
# {"entities": {"fauna": ["B. onoideus", "Brachiodontes"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "B. onoideus",
#         "Brachiodontes"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['varech'], 'flora': []}}
#
# {"entities": {"fauna": ["varech"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "varech"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Teleoceras hrachypus'], 'flora': []}}
#
# {"entities": {"fauna": ["Teleoceras hrachypus"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Teleoceras hrachypus"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['corhme', 'mastodontes'], 'flora': []}}
#
# {"entities": {"fauna": ["corhme", "mastodontes"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "corhme",
#         "mastodontes"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['oignon']}}
#
# {"entities": {"fauna": ["chien"], "flora": ["oignon"]}}
#
# {
# "entities": {
#     "fauna": [
#         "chien"
#     ],
#     "flora": [
#         "oignon"
#     ]
# }
# }
#
# {'entities': {'fauna': ['TIRONENSIS', 'Famille des ANTHRAGOTHÉRIDÉS', 'Genre BRACHYODUS'], 'flora': []}}
#
# {"entities": {"fauna": ["TIRONENSIS", "Famille des ANTHRAGOTHÉRIDÉS", "Genre BRACHYODUS"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "TIRONENSIS",
#             "Famille des ANTHRAGOTHÉRIDÉS",
#             "Genre BRACHYODUS"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': [], 'flora': ['plantes sèches']}}
#
# {"entities": {"fauna": ["oiseau"], "flora": ["plantes sèches"]}}
#
# {
# "entities": {
# "fauna": [
# "oiseau"
# ],
# "flora": [
# "plantes sèches"
# ]
# }
# }
#
# {'entities': {'fauna': ['vermine'], 'flora': []}}
#
# {"entities": {"fauna": ["vermin"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "vermin"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Palaeotherium'], 'flora': []}}
#
# {"entities": {"fauna": ["Palaeotherium"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Palaeotherium"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Rhinocéros (Ceratorhinos)'], 'flora': []}}
#
# {"entities": {"fauna": ["Rhinoceros"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Rhinoceros"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Macrotherium grande'], 'flora': []}}
#
# {"entities": {"fauna": ["Macrotherium grande"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Macrotherium grande"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['garçon marchand de vin', 'Honoré Ulbach'], 'flora': []}}
#
# {"entities": {"fauna": ["garçon marchand de vin", "Honoré Ulbach"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "garçon marchand de vin",
#             "Honoré Ulbach"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': ['postillon', 'cheval'], 'flora': []}}
#
# {"entities": {"fauna": ["postillon", "cheval"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "postillon",
# "cheval"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['papillons']}}
#
# {"entities": {"fauna": ["oiseaux"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "oiseaux"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Macrotherium', 'gigantesque'], 'flora': []}}
#
# {"entities": {"fauna": ["Macrotherium", "gigantesque"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Macrotherium",
#         "gigantesque"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['poissons'], 'flora': []}}
#
# {"entities": {"fauna": ["poissons"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "poissons"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Dicrocerus elegans'], 'flora': []}}
#
# {"entities": {"fauna": ["Dicrocerus elegans"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Dicrocerus elegans"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['poissons volants'], 'flora': []}}
#
# {"entities": {"fauna": ["poissons volants"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "poissons volants"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': ['fruits']}}
#
# {"entities": {"fauna": ["cat"], "flora": ["flowers", "fruits"]}}
#
# {
# "entities": {
#     "fauna": [
#         "cat"
#     ],
#     "flora": [
#         "flowers",
#         "fruits"
#     ]
# }
# }
#
# {'entities': {'fauna': ['B. onoideus'], 'flora': []}}
#
# {"entities": {"fauna": ["B. onoideus"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "B. onoideus"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['caméléons', 'boas', 'crocodiles'], 'flora': []}}
#
# {"entities": {"fauna": ["caméleons", "boa", "crocodile"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "caméleons",
#         "boa",
#         "crocodile"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['bananiers'], 'flora': []}}
#
# {"entities": {"fauna": ["bananiers"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "bananiers"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['rats', 'chouettes'], 'flora': []}}
#
# {"entities": {"fauna": ["rats", "chouettes"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "rats",
# "chouettes"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Mammifères miocènes', 'l\'Orléanais'], 'flora': []}}
#
# {"entities": {"fauna": ["Mammifères miocènes", "l'Orléanais"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "Mammifères miocènes",
#             "l'Orléanais"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': ['chamois'], 'flora': []}}
#
# {"entities": {"fauna": ["chamois"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "chamois"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['palmiers'], 'flora': []}}
#
# {"entities": {"fauna": ["palmiers"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "palmiers"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['oiseaux', 'insectes', 'grand crabe', 'poissons se nourrissant de coraux'], 'flora': ['corail piquant']}}
#
# {"entities": {"fauna": ["oiseaux", "insectes", "grand crabe", "poissons se nourrissant de coraux"], "flora": ["corail piquant"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "oiseaux",
#             "insectes",
#             "grand crabe",
#             "poissons se nourrissant de coraux"
#         ],
#         "flora": [
#             "corail piquant"
#         ]
#     }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': ['bêtes blanches'], 'flora': []}}
#
# {"entities": {"fauna": ["bête noire", "bête blanche"], "flora": ["rose"]}}
#
# {
# "entities": {
#     "fauna": [
#         "bête noire",
#         "bête blanche"
#     ],
#     "flora": [
#         "rose"
#     ]
# }
# }
#
# {'entities': {'fauna': ['hommes', 'femmes', 'chien', 'vache', 'enfants', 'cochon'], 'flora': []}}
#
# {"entities": {"fauna": ["hommes", "femmes", "chien", "vache", "enfants", "cochon"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "hommes",
#             "femmes",
#             "chien",
#             "vache",
#             "enfants",
#             "cochon"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': ['bon père'], 'flora': []}}
#
# {"entities": {"fauna": ["bon père"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "bon père"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Mastodontes', 'Palæothères'], 'flora': []}}
#
# {"entities": {"fauna": ["Mammoths", "Palaeotheres"], "flora": ["Cycads"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "Mammoths",
#             "Palaeotheres"
#         ],
#         "flora": [
#             "Cycads"
#         ]
#     }
# }
#
# {'entities': {'fauna': [], 'flora': ['graines']}}
#
# {"entities": {"fauna": ["oiseau"], "flora": ["fleur"]}}
#
# {
# "entities": {
#     "fauna": [
#         "oiseau"
#     ],
#     "flora": [
#         "fleur"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Teieoceras'], 'flora': []}}
#
# {"entities": {"fauna": ["Teieoceras"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Teieoceras"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['marsouins', 'dauphins', 'poissons volants'], 'flora': []}}
#
# {"entities": {"fauna": ["marsouins", "dauphins", "poissons volants"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "marsouins",
#             "dauphins",
#             "poissons volants"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': ['Mammifères miocènes', 'sables de rOrléanais et des faluns de la Touraine'], 'flora': []}}
#
# {"entities": {"fauna": ["Mammifères miocènes", "sables de rOrléanais et des faluns de la Touraine"], "flora": []}}
#
# {
#     "entities": {
#         "fauna": [
#             "Mammifères miocènes",
#             "sables de rOrléanais et des faluns de la Touraine"
#         ],
#         "flora": []
#     }
# }
#
# {'entities': {'fauna': ['Anchitherium', 'Pnlœolherium'], 'flora': []}}
#
# {"entities": {"fauna": ["Anchitherium", "Pnlœolherium"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Anchitherium",
#         "Pnlœolherium"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Chalicotherium magnum']}}
#
# {"entities": {"fauna": ["Chalicotherium magnum"]}}
#
# {
# "entities": {
#     "fauna": [
#         "Chalicotherium magnum"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Teleoceras Goldjiissi'], 'flora': []}}
#
# {"entities": {"fauna": ["Teleoceras Goldjiissi"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Teleoceras Goldjiissi"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Anchitherium', 'aurelianense'], 'flora': []}}
#
# {"entities": {"fauna": ["Anchitherium", "aurelianense"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Anchitherium",
#         "aurelianense"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['Santa-Ana', 'San Borja'], 'flora': ['plantations d\'arbres fruitiers', 'infinité d\'autre^ travaux', 'eau de fleur d\'oranger']}}
#
# {"entities": {"fauna": ["Santa-Ana", "San Borja"], "flora": ["plantations d'arbres fruitiers", "infinité d'autres travaux", "eau de fleur d'oranger"]}}
#
# {
#     "entities": {
#         "fauna": [
#             "Santa-Ana",
#             "San Borja"
#         ],
#         "flora": [
#             "plantations d'arbres fruitiers",
#             "infinité d'autres travaux",
#             "eau de fleur d'oranger"
#         ]
#     }
# }
#
# {'entities': {'fauna': [], 'flora': ['graines', 'plantes']}}
#
# {"entities": {"fauna": ["oiseau", "renard"], "flora": ["arbre", "fleur"]}}
#
# {
# "entities": {
#     "fauna": [
#         "oiseau",
#         "renard"
#     ],
#     "flora": [
#         "arbre",
#         "fleur"
#     ]
# }
# }
#
# {'entities': {'fauna': ['Equidé', 'espèces'], 'flora': []}}
#
# {"entities": {"fauna": ["Equidé", "espèces"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "Equid\u03c1",
# "esp\u03b4es"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['animal'], 'flora': []}}
#
# {"entities": {"fauna": ["animal"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "animal"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['chevaux'], 'flora': []}}
#
# {"entities": {"fauna": ["chevaux"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "chevaux"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['Cervus', 'Palœomeryx'], 'flora': []}}
#
# {"entities": {"fauna": ["Cervus", "Palœomeryx"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "Cervus",
#         "Palœomeryx"
#     ],
#     "flora": []
# }
# }
#
# {'entities': {'fauna': ['palmiers'], 'flora': ['maisons', 'terrasses']}}
#
# {"entities": {"fauna": ["palmiers"], "flora": ["maisons", "terrasses"]}}
#
# {
# "entities": {
#     "fauna": [
#         "palmiers"
#     ],
#     "flora": [
#         "maisons",
#         "terrasses"
#     ]
# }
# }
#
# {'entities': {'fauna': ['espèce d\'atoll'], 'flora': []}}
#
# {"entities": {"fauna": ["espèce d'atoll"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "espèce d'atoll"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': [], 'flora': []}}
#
# {"entities": {"fauna": ["lion", "elephant"], "flora": ["tree"]}}
#
# {
# "entities": {
#     "fauna": [
#         "lion",
#         "elephant"
#     ],
#     "flora": [
#         "tree"
#     ]
# }
# }
#
# {'entities': {'fauna': ['rats', 'lapins'], 'flora': []}}
#
# {"entities": {"fauna": ["rats", "lapins"], "flora": []}}
#
# {
# "entities": {
# "fauna": [
# "rats",
# "lapins"
# ],
# "flora": []
# }
# }
#
# {'entities': {'fauna': ['oies'], 'flora': []}}
#
# {"entities": {"fauna": ["oies"], "flora": []}}
#
# {
# "entities": {
#     "fauna": [
#         "oies"
#     ],
#     "flora": []
# }
# }

# %%
dev.to_csv("/home/tess/generative_exp/Local_LLM/output_loops_LLM/dev_French_prompt_V_mistral.csv", index= False)

# %% [markdown]
# # Evaluate the results of the LLM
#
# 💡 Done! We have saved the results of our LLM NER extraction system to a .CSV.
# If you are interested to see how we evaluated the LLM results, go to the Notebook ***Evaluate_LLM_output***.
